# %%
#Powershell + C# vs Python Comparator

#install powershell
# %%bash
wget https://packages.microsoft.com/config/ubuntu/22.04/packages-microsoft-prod.deb -O packages-microsoft-prod.deb
sudo dpkg -i packages-microsoft-prod.deb
sudo apt-get update
sudo apt-get install -y apt-transport-https
sudo apt-get install -y powershell=7.3.8-1.deb

# %%
# check powershell
# %%bash
pwsh -v
# Out:
# PowerShell 7.3.8

# %%
# write script powershell
# %%writefile test_powershell.ps1
<#
.SYNOPSIS
PowerShell + C# Performance Test
Compatible with PowerShell 5.1 and 7+
#>

$code = @"
using System;
using System.Diagnostics;

public static class PerfTest {
    public static long SumNumbers(long n) {
        long sum = 0;
        for (long i = 0; i < n; i++) sum += i;
        return sum;
    }

    public static double Measure(long n) {
        var sw = Stopwatch.StartNew();
        long result = SumNumbers(n);
        sw.Stop();
        Console.WriteLine(string.Format("Result: {0}", result));
        return sw.Elapsed.TotalSeconds;
    }
}
"@

Add-Type -TypeDefinition $code -Language CSharp

# Number of iterations
$n = 100000000  # 100 million

Write-Host "Starting PowerShell + C# test..."
$tempo = [PerfTest]::Measure($n)
Write-Host ("Total time: {0:N3} seconds" -f $tempo)

# %%
# run powershell script
# sum of 100 million numbers
# !pwsh -File test_powershell.ps1

# %%
# install python 3.14
# !sudo add-apt-repository ppa:deadsnakes/ppa
# !sudo apt update
# !sudo apt install python3.14

# %%
# version python
# !python3.14 --version
# Out:
# Python 3.14.0

# %%
# run python
# sum of 100 million numbers
# %%writefile test_python.py
import time

def sum_numbers(n: int) -> int:
    s = 0
    for i in range(n):
        s += i
    return s

if __name__ == "__main__":
    n = 100_000_000  # 100 milhões
    print("Starting Python test...")
    start = time.time()
    result = sum_numbers(n)
    end = time.time()
    print(f"Result: {result}")
    print(f"Total time: {end - start:.3f} seconds")
    n = 50  # comprimento da linha
    print("-" * n)

# %%
# run python
# sum of 1 billion numbers
# %%writefile test_python_1b.py
import time

def sum_numbers(n: int) -> int:
    s = 0
    for i in range(n):
        s += i
    return s

if __name__ == "__main__":
    n = 1_000_000_000  # 1 bi
    print("Starting Python test...")
    start = time.time()
    result = sum_numbers(n)
    end = time.time()
    print(f"Result: {result}")
    print(f"Total time: {end - start:.3f} seconds")
    n = 50  # comprimento da linha
    print("-" * n)

# %%
# run python with mathematical
# sum of 100 million numbers
# %%writefile test_python_mathematical.py
import time
def sum_numbers_formula(n: int) -> int:
    return n * (n - 1) // 2  # // para divisão inteira

if __name__ == "__main__":
    n = 100_000_000  # 100 milhões
    print("Starting Python test mathematical (formula)...")
    start = time.time()
    result = sum_numbers_formula(n)
    end = time.time()
    print(f"Result: {result}")
    print(f"Total time: {end - start:.6f} seconds")
    n = 50  # comprimento da linha
    print("-" * n)

# %%
# run python with mathematical
# sum of 1 billion numbers
# %%writefile test_python_mathematical_1b.py
import time
def sum_numbers_formula(n: int) -> int:
    return n * (n - 1) // 2  # // para divisão inteira

if __name__ == "__main__":
    n = 1_000_000_000  # 1b
    print("Starting Python test mathematical (formula)...")
    start = time.time()
    result = sum_numbers_formula(n)
    end = time.time()
    print(f"Result: {result}")
    print(f"Total time: {end - start:.6f} seconds")
    n = 50  # comprimento da linha
    print("-" * n)

# %%
# run test python normal
# python default
# !python3 test_python.py
#python 3.14
# !python3.14 test_python.py

# %%
# run test python default mathematical
# !python3 test_python_mathematical.py
# run test python 3.14 mathematical
# !python3.14 test_python_mathematical.py

# %%
# 1 bi test python normal
# !python3 test_python_1b.py
#python 3.14
# !python3.14 test_python_1b.py

# %%
# test 1bi python 3.14 mathematical
# run test python default mathematical 1b
# !python3 test_python_mathematical_1b.py
# run test python 3.14 mathematical
# !python3.14 test_python_mathematical_1b.py
